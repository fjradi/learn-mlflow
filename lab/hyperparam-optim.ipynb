# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras
import numpy as np
import pandas as pd
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import mlflow
from mlflow.models import infer_signature

# %%
# Set our tracking server uri for logging
mlflow.set_tracking_uri(uri="http://127.0.0.1:4500")

# %%
# Load dataset
data = pd.read_csv(
    "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-white.csv",
    sep=";",
)

# Split the data into training, validation, and test sets
train, test = train_test_split(data, test_size=0.25, random_state=42)
train_x = train.drop(["quality"], axis=1).values
train_y = train[["quality"]].values.ravel()
test_x = test.drop(["quality"], axis=1).values
test_y = test[["quality"]].values.ravel()
train_x, valid_x, train_y, valid_y = train_test_split(
    train_x, train_y, test_size=0.2, random_state=42
)
signature = infer_signature(train_x, train_y)

# %%
def train_model(params, epochs, train_x, train_y, valid_x, valid_y, test_x, test_y):
    # Define model architecture
    mean = np.mean(train_x, axis=0)
    var = np.var(train_x, axis=0)
    model = keras.Sequential(
        [
            keras.Input([train_x.shape[1]]),
            keras.layers.Normalization(mean=mean, variance=var),
            keras.layers.Dense(64, activation="relu"),
            keras.layers.Dense(1),
        ]
    )

    # Compile model
    model.compile(
        optimizer=keras.optimizers.SGD(
            learning_rate=params["lr"], momentum=params["momentum"]
        ),
        loss="mean_squared_error",
        metrics=[keras.metrics.RootMeanSquaredError()],
    )

    # Train model with MLflow tracking
    with mlflow.start_run(nested=True):
        model.fit(
            train_x,
            train_y,
            validation_data=(valid_x, valid_y),
            epochs=epochs,
            batch_size=64,
        )
        # Evaluate the model
        eval_result = model.evaluate(valid_x, valid_y, batch_size=64)
        eval_rmse = eval_result[1]

        # Log parameters and results
        mlflow.log_params(params)
        mlflow.log_metric("eval_rmse", eval_rmse)

        # Log model
        mlflow.tensorflow.log_model(model, "model", signature=signature)

        return {"loss": eval_rmse, "status": STATUS_OK, "model": model}

# %%
def objective(params):
    # MLflow will track the parameters and results for each run
    result = train_model(
        params,
        epochs=3,
        train_x=train_x,
        train_y=train_y,
        valid_x=valid_x,
        valid_y=valid_y,
        test_x=test_x,
        test_y=test_y,
    )
    return result

# %%
space = {
    "lr": hp.loguniform("lr", np.log(1e-5), np.log(1e-1)),
    "momentum": hp.uniform("momentum", 0.0, 1.0),
}

# %%
mlflow.set_experiment("/wine-quality")
with mlflow.start_run():
    # Conduct the hyperparameter search using Hyperopt
    trials = Trials()
    best = fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=8,
        trials=trials,
    )

    # Fetch the details of the best run
    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    # Log the best parameters, loss, and model
    mlflow.log_params(best)
    mlflow.log_metric("eval_rmse", best_run["loss"])
    mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)

    # Print out the best parameters and corresponding loss
    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")
# Out:
# 2024/05/22 22:19:03 INFO mlflow.tracking.fluent: Experiment with name '/wine-quality' does not exist. Creating a new experiment.
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 13s 295ms/step - loss: 34.9898 - root_mean_squared_error: 5.9152
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29.7172 - root_mean_squared_error: 5.4417 - val_loss: 14.3052 - val_root_mean_squared_error: 3.7822
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14.9751 - root_mean_squared_error: 3.8698
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.8855 - root_mean_squared_error: 3.4394 - val_loss: 5.6713 - val_root_mean_squared_error: 2.3815
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.3849 - root_mean_squared_error: 2.3205
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 4.9097 - root_mean_squared_error: 2.2131 - val_loss: 3.0945 - val_root_mean_squared_error: 1.7591
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.1175 - root_mean_squared_error: 1.7656
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step - loss: 3.1280 - root_mean_squared_error: 1.7685
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 13s 301ms/step - loss: 34.2591 - root_mean_squared_error: 5.8531
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.4956 - root_mean_squared_error: 4.6916 - val_loss: 3.4179 - val_root_mean_squared_error: 1.8487
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.9179 - root_mean_squared_error: 1.9794
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8838 - root_mean_squared_error: 1.6957 - val_loss: 2.2030 - val_root_mean_squared_error: 1.4842
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8018 - root_mean_squared_error: 1.3423
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1044 - root_mean_squared_error: 1.4500 - val_loss: 1.8413 - val_root_mean_squared_error: 1.3569
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6200 - root_mean_squared_error: 1.2728
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 1.8824 - root_mean_squared_error: 1.3713
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 13s 295ms/step - loss: 39.2066 - root_mean_squared_error: 6.2615
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.2820 - root_mean_squared_error: 5.7615 - val_loss: 16.7893 - val_root_mean_squared_error: 4.0975
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14.6851 - root_mean_squared_error: 3.8321
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.3167 - root_mean_squared_error: 3.6417 - val_loss: 6.3626 - val_root_mean_squared_error: 2.5224
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0763 - root_mean_squared_error: 2.8419
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 5.3635 - root_mean_squared_error: 2.3110 - val_loss: 3.3507 - val_root_mean_squared_error: 1.8305
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.3625 - root_mean_squared_error: 1.8337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 3.3347 - root_mean_squared_error: 1.8260
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 13s 302ms/step - loss: 43.8549 - root_mean_squared_error: 6.6223
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21.7409 - root_mean_squared_error: 4.5710 - val_loss: 2.3806 - val_root_mean_squared_error: 1.5429
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.0357 - root_mean_squared_error: 1.7423
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0807 - root_mean_squared_error: 1.4407 - val_loss: 1.6486 - val_root_mean_squared_error: 1.2840
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0144 - root_mean_squared_error: 1.4193
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5254 - root_mean_squared_error: 1.2339 - val_loss: 1.3763 - val_root_mean_squared_error: 1.1732
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2827 - root_mean_squared_error: 1.1326
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4346 - root_mean_squared_error: 1.1971
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 15s 350ms/step - loss: 33.5628 - root_mean_squared_error: 5.7933
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.6598 - root_mean_squared_error: 3.9763 - val_loss: 2.1279 - val_root_mean_squared_error: 1.4587
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.6517 - root_mean_squared_error: 1.2852
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0230 - root_mean_squared_error: 1.4204 - val_loss: 1.6578 - val_root_mean_squared_error: 1.2876
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2549 - root_mean_squared_error: 1.1202
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6340 - root_mean_squared_error: 1.2761 - val_loss: 1.4040 - val_root_mean_squared_error: 1.1849
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2056 - root_mean_squared_error: 1.0980
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 1.4183 - root_mean_squared_error: 1.1902
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 14s 316ms/step - loss: 36.7733 - root_mean_squared_error: 6.0641
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.6387 - root_mean_squared_error: 5.8853 - val_loss: 33.3029 - val_root_mean_squared_error: 5.7709
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 31.6887 - root_mean_squared_error: 5.6293
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32.7609 - root_mean_squared_error: 5.7236 - val_loss: 31.8674 - val_root_mean_squared_error: 5.6451
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 33.7058 - root_mean_squared_error: 5.8057
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.9713 - root_mean_squared_error: 5.6541 - val_loss: 30.4975 - val_root_mean_squared_error: 5.5225
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.0056 - root_mean_squared_error: 5.4777
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 29.9196 - root_mean_squared_error: 5.4698
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 16s 359ms/step - loss: 41.0623 - root_mean_squared_error: 6.4080
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 18.5416 - root_mean_squared_error: 4.1654 - val_loss: 1.7509 - val_root_mean_squared_error: 1.3232
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.8564 - root_mean_squared_error: 1.3625
# 29/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5592 - root_mean_squared_error: 1.2482
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5156 - root_mean_squared_error: 1.2306 - val_loss: 1.3306 - val_root_mean_squared_error: 1.1535
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.2998 - root_mean_squared_error: 1.5165
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2833 - root_mean_squared_error: 1.1306 - val_loss: 1.1319 - val_root_mean_squared_error: 1.0639
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9453 - root_mean_squared_error: 0.9723
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 1.1422 - root_mean_squared_error: 1.0680
#
# Epoch 1/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 30s 682ms/step - loss: 36.6284 - root_mean_squared_error: 6.0521
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 30.9141 - root_mean_squared_error: 5.5538 - val_loss: 17.9365 - val_root_mean_squared_error: 4.2352
#
# Epoch 2/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 18.7861 - root_mean_squared_error: 4.3343
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 15.2910 - root_mean_squared_error: 3.9043 - val_loss: 8.5077 - val_root_mean_squared_error: 2.9168
#
# Epoch 3/3
#
#  1/46 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 7.6324 - root_mean_squared_error: 2.7627
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2348 - root_mean_squared_error: 2.6867 - val_loss: 4.4204 - val_root_mean_squared_error: 2.1025
#
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9837 - root_mean_squared_error: 2.2324
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 4.4580 - root_mean_squared_error: 2.1110
#
# 100%|██████████| 8/8 [00:50<00:00,  6.36s/trial, best loss: 1.0638916492462158]
# Best parameters: {'lr': 0.0023582948488154627, 'momentum': 0.696450255477604}
# Best eval rmse: 1.0638916492462158
